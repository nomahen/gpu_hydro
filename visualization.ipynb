# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
files = ["init","100001","100002","100003","100004","100005","100006","100007","100008","100009","100010","100011","100012","100013","100014","100015","100016","100017","100018"]
path_pre = "/home/nkaaz/research/software/gpu_hydro/runs/shuOsher_3D/output/output_"
for fn in files:
    plt.clf()
    path = path_pre +  fn + ".txt"
    from read_data import *
    read_data(path,128,16,16)
    plt.contourf(x[:,:,0],y[:,:,0],rho[:,:,0])
    plt.savefig("plots/" + fn + ".png")
    plt.show()
